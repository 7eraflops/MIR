# %%
# Spleeter separation (CPU-only) with museval evaluation
# This cell performs separation only and saves outputs under temp_estimates/spleeter_2stems/<subset>/
# and writes museval JSON outputs to temp_output/spleeter_2stems/ so the main notebook can compare models.
# It forces TensorFlow to use CPU by clearing CUDA_VISIBLE_DEVICES before importing Spleeter/TensorFlow.

import os
import numpy as np
import soundfile as sf
import musdb
import museval

# Force TensorFlow to use CPU (must be set before importing Spleeter/TensorFlow)
os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

from spleeter.separator import Separator

# Paths
path_to_folder = "."
musdb_root = os.path.join(path_to_folder, "musdb18")
estimates_base_path = os.path.join(path_to_folder, "estimates")
output_base_path = os.path.join(path_to_folder, "output")

model_name = "spleeter_2stems"
estimates_path = os.path.join(estimates_base_path, model_name)
output_path = os.path.join(output_base_path, model_name)

os.makedirs(estimates_path, exist_ok=True)
os.makedirs(output_path, exist_ok=True)

# Initialize Spleeter (2 stems: vocals + accompaniment)
separator = Separator("spleeter:2stems")

# Load MUSDB (main notebook handles download; here we avoid redownloading)
mus = musdb.DB(root=musdb_root, download=False)

for track in mus:
    print(f"[→] Separating: {track.name}")

    # Ensure audio is float32 to avoid TensorFlow dtype mismatches
    audio = track.audio.astype(np.float32)  # shape: (samples, channels)
    rate = track.rate
    subset = track.subset

    try:
        prediction = separator.separate(audio)
    except Exception as e:
        print(f"Spleeter separation failed for {track.name}: {e}")
        continue

    # prediction contains 'vocals' and 'accompaniment' as numpy arrays (samples, channels)
    estimates = {
        "vocals": np.asarray(prediction["vocals"], dtype=np.float32),
        "accompaniment": np.asarray(prediction["accompaniment"], dtype=np.float32),
    }

    # Prepare estimates for museval: museval expects numpy arrays shape (samples, channels)
    cpu_estimates = {key: arr for key, arr in estimates.items()}

    # Evaluate with museval and write JSON outputs into output_path
    try:
        scores = museval.eval_mus_track(track, cpu_estimates, output_dir=output_path)
        print(scores)
    except Exception as e:
        print(f"Museval evaluation failed for {track.name}: {e}")

    # Create subset folder and save wavs following the main notebook convention
    subset_path = os.path.join(estimates_path, subset)
    os.makedirs(subset_path, exist_ok=True)

    for target, audio_np in estimates.items():
        file_name = f"{track.name} - {target}.wav"
        out_path = os.path.join(subset_path, file_name)
        sf.write(out_path, audio_np, rate)

print("Spleeter separation complete.")
# Out:
# [→] Separating: A Classic Education - NightOwl
# INFO:spleeter:Downloading model archive https://github.com/deezer/spleeter/releases/download/v1.4.0/2stems.tar.gz
# INFO:spleeter:Validating archive checksum
# INFO:spleeter:Extracting downloaded 2stems archive
# INFO:spleeter:2stems model file(s) extracted
# WARNING:tensorflow:From /home/teraflops/.pyenv/versions/MIR_spleeter_env/lib/python3.10/site-packages/spleeter/separator.py:65: RunConfig.__init__ (from tensorflow_estimator.python.estimator.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /home/teraflops/.pyenv/versions/MIR_spleeter_env/lib/python3.10/site-packages/spleeter/separator.py:67: Estimator.__init__ (from tensorflow_estimator.python.estimator.estimator) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# INFO:tensorflow:Using config: {'_model_dir': 'pretrained_models/2stems', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.7
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# WARNING:tensorflow:From /home/teraflops/.pyenv/versions/MIR_spleeter_env/lib/python3.10/site-packages/keras/layers/normalization/batch_normalization.py:581: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# WARNING:tensorflow:From /home/teraflops/.pyenv/versions/MIR_spleeter_env/lib/python3.10/site-packages/spleeter/model/__init__.py:524: EstimatorSpec.__new__ (from tensorflow_estimator.python.estimator.model_fn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /home/teraflops/.pyenv/versions/MIR_spleeter_env/lib/python3.10/site-packages/tensorflow/python/saved_model/model_utils/export_utils.py:366: PredictOutput.__init__ (from tensorflow.python.saved_model.model_utils.export_output) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From /home/teraflops/.pyenv/versions/MIR_spleeter_env/lib/python3.10/site-packages/tensorflow/python/training/monitored_session.py:1455: SessionRunArgs.__new__ (from tensorflow.python.training.session_run_hook) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /home/teraflops/.pyenv/versions/MIR_spleeter_env/lib/python3.10/site-packages/tensorflow/python/training/monitored_session.py:1454: SessionRunContext.__init__ (from tensorflow.python.training.session_run_hook) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# WARNING:tensorflow:From /home/teraflops/.pyenv/versions/MIR_spleeter_env/lib/python3.10/site-packages/tensorflow/python/training/monitored_session.py:1474: SessionRunValues.__new__ (from tensorflow.python.training.session_run_hook) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.keras instead.
# vocals          ==> SDR:   4.061  SIR:   8.478  ISR:   5.400  SAR:   4.078
# accompaniment   ==> SDR:  12.660  SIR:  14.022  ISR:  22.130  SAR:  17.529
#
# [→] Separating: ANiMAL - Clinic A
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.841  SIR:  13.938  ISR:  10.175  SAR:   5.978
# accompaniment   ==> SDR:  13.685  SIR:  18.004  ISR:  22.570  SAR:  15.876
#
# [→] Separating: ANiMAL - Easy Tiger
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.104  SIR:  13.637  ISR:  10.379  SAR:   5.964
# accompaniment   ==> SDR:  13.758  SIR:  20.347  ISR:  18.821  SAR:  15.445
#
# [→] Separating: ANiMAL - Rockshow
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   4.568  SIR:   8.029  ISR:  12.053  SAR:   5.632
# accompaniment   ==> SDR:   9.701  SIR:  16.724  ISR:  15.413  SAR:  11.485
#
# [→] Separating: Actions - Devil's Words
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.896  SIR:  16.740  ISR:  13.808  SAR:   9.513
# accompaniment   ==> SDR:   9.909  SIR:  14.266  ISR:  17.240  SAR:  11.000
#
# [→] Separating: Actions - One Minute Smile
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.907  SIR:  15.746  ISR:   9.777  SAR:   7.399
# accompaniment   ==> SDR:   9.438  SIR:  11.314  ISR:  18.164  SAR:  10.428
#
# [→] Separating: Actions - South Of The Water
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.170  SIR:  19.968  ISR:  10.190  SAR:   8.750
# accompaniment   ==> SDR:  11.505  SIR:  15.256  ISR:  14.033  SAR:  13.421
#
# [→] Separating: Aimee Norwich - Child
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.220  SIR:  15.961  ISR:  12.950  SAR:   7.493
# accompaniment   ==> SDR:  18.976  SIR:  23.801  ISR:  25.450  SAR:  19.172
#
# [→] Separating: Alexander Ross - Goodbye Bolero
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.168  SIR:  12.439  ISR:  12.764  SAR:   8.700
# accompaniment   ==> SDR:  10.826  SIR:  15.863  ISR:  15.873  SAR:  12.230
#
# [→] Separating: Alexander Ross - Velvet Curtain
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   3.782  SIR:   9.735  ISR:   5.387  SAR:   5.614
# accompaniment   ==> SDR:  10.366  SIR:  12.120  ISR:  19.376  SAR:  16.005
#
# [→] Separating: Angela Thomas Wade - Milk Cow Blues
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.247  SIR:  12.417  ISR:   8.905  SAR:   7.363
# accompaniment   ==> SDR:   9.657  SIR:  14.085  ISR:  17.760  SAR:  13.025
#
# [→] Separating: Atlantis Bound - It Was My Fault For Waiting
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.627  SIR:  18.248  ISR:  12.992  SAR:   9.675
# accompaniment   ==> SDR:  14.643  SIR:  18.443  ISR:  22.704  SAR:  15.732
#
# [→] Separating: Auctioneer - Our Future Faces
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.178  SIR:  11.175  ISR:  12.534  SAR:   7.497
# accompaniment   ==> SDR:   9.910  SIR:  14.782  ISR:  17.455  SAR:  11.920
#
# [→] Separating: AvaLuna - Waterduct
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.958  SIR:  17.221  ISR:   8.214  SAR:   9.306
# accompaniment   ==> SDR:  12.332  SIR:  13.904  ISR:  23.025  SAR:  15.970
#
# [→] Separating: BigTroubles - Phantom
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.355  SIR:  14.722  ISR:  10.598  SAR:   8.509
# accompaniment   ==> SDR:  13.020  SIR:  14.952  ISR:  20.690  SAR:  15.039
#
# [→] Separating: Bill Chudziak - Children Of No-one
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.619  SIR:  12.812  ISR:  13.938  SAR:   8.004
# accompaniment   ==> SDR:  10.289  SIR:  16.957  ISR:  16.783  SAR:  11.876
#
# [→] Separating: Black Bloc - If You Want Success
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   1.817  SIR:   6.407  ISR:   2.777  SAR:   3.309
# accompaniment   ==> SDR:   8.895  SIR:   8.949  ISR:  20.071  SAR:  15.654
#
# [→] Separating: Celestial Shore - Die For Us
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.801  SIR:  15.246  ISR:   8.915  SAR:   5.534
# accompaniment   ==> SDR:   9.816  SIR:  11.213  ISR:  18.403  SAR:   9.352
#
# [→] Separating: Chris Durban - Celebrate
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.091  SIR:  12.220  ISR:   7.389  SAR:   5.988
# accompaniment   ==> SDR:   9.985  SIR:  12.223  ISR:  18.346  SAR:  12.894
#
# [→] Separating: Clara Berry And Wooldog - Air Traffic
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.238  SIR:  11.734  ISR:   6.936  SAR:   5.691
# accompaniment   ==> SDR:  10.288  SIR:  12.266  ISR:  18.839  SAR:  14.230
#
# [→] Separating: Clara Berry And Wooldog - Stella
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   9.243  SIR:  17.246  ISR:  12.826  SAR:  10.241
# accompaniment   ==> SDR:  13.709  SIR:  16.686  ISR:  21.032  SAR:  14.548
#
# [→] Separating: Clara Berry And Wooldog - Waltz For My Victims
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.029  SIR:  18.189  ISR:  11.464  SAR:   9.631
# accompaniment   ==> SDR:  12.192  SIR:  15.728  ISR:  21.829  SAR:  16.031
#
# [→] Separating: Cnoc An Tursa - Bannockburn
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   2.660  SIR:   7.730  ISR:   4.041  SAR:   1.906
# accompaniment   ==> SDR:   9.585  SIR:  10.771  ISR:  19.418  SAR:  14.411
#
# [→] Separating: Creepoid - OldTree
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   9.654  SIR:  18.009  ISR:  11.951  SAR:  11.485
# accompaniment   ==> SDR:   9.555  SIR:  11.020  ISR:  15.472  SAR:  11.500
#
# [→] Separating: Dark Ride - Burning Bridges
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.781  SIR:  14.629  ISR:   9.607  SAR:  13.244
# accompaniment   ==> SDR:  14.049  SIR:  16.050  ISR:  21.516  SAR:  18.591
#
# [→] Separating: Dreamers Of The Ghetto - Heavy Love
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.111  SIR:   8.294  ISR:  10.144  SAR:   7.364
# accompaniment   ==> SDR:   7.501  SIR:  10.787  ISR:  13.191  SAR:   9.330
#
# [→] Separating: Drumtracks - Ghost Bitch
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.776  SIR:  15.922  ISR:  13.489  SAR:  10.323
# accompaniment   ==> SDR:  10.794  SIR:  15.120  ISR:  18.960  SAR:  13.381
#
# [→] Separating: Faces On Film - Waiting For Ga
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   3.927  SIR:   7.912  ISR:   7.491  SAR:   4.074
# accompaniment   ==> SDR:   7.413  SIR:   9.841  ISR:  15.364  SAR:   9.985
#
# [→] Separating: Fergessen - Back From The Start
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   0.575  SIR:   2.752  ISR:   9.625  SAR:   4.585
# accompaniment   ==> SDR:   6.310  SIR:  12.973  ISR:   8.925  SAR:   7.536
#
# [→] Separating: Fergessen - Nos Palpitants
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  10.774  SIR:  15.553  ISR:  11.142  SAR:   9.526
# accompaniment   ==> SDR:   8.555  SIR:   8.711  ISR:  12.776  SAR:   7.730
#
# [→] Separating: Fergessen - The Wind
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   9.041  SIR:  14.130  ISR:  12.339  SAR:   8.569
# accompaniment   ==> SDR:   9.215  SIR:  10.087  ISR:  16.732  SAR:   9.715
#
# [→] Separating: Flags - 54
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   9.841  SIR:  25.967  ISR:   9.588  SAR:  11.462
# accompaniment   ==> SDR:  12.858  SIR:  12.949  ISR:  23.377  SAR:  17.336
#
# [→] Separating: Giselle - Moss
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.501  SIR:  16.804  ISR:   7.381  SAR:  11.761
# accompaniment   ==> SDR:  10.081  SIR:  11.120  ISR:  18.634  SAR:  16.991
#
# [→] Separating: Grants - PunchDrunk
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  13.575  SIR:  18.297  ISR:  21.697  SAR:  13.999
# accompaniment   ==> SDR:  17.914  SIR:  25.291  ISR:  22.609  SAR:  18.491
#
# [→] Separating: Helado Negro - Mitad Del Mundo
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.625  SIR:  12.440  ISR:  15.237  SAR:   9.801
# accompaniment   ==> SDR:   7.562  SIR:  14.118  ISR:  13.031  SAR:   8.602
#
# [→] Separating: Hezekiah Jones - Borrowed Heart
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   2.843  SIR:  11.413  ISR:   4.483  SAR:   1.967
# accompaniment   ==> SDR:   9.378  SIR:  10.761  ISR:  23.003  SAR:  14.623
#
# [→] Separating: Hollow Ground - Left Blind
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.289  SIR:  12.227  ISR:   9.832  SAR:   5.279
# accompaniment   ==> SDR:  11.259  SIR:  15.419  ISR:  17.433  SAR:  11.748
#
# [→] Separating: Hop Along - Sister Cities
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   9.869  SIR:  15.640  ISR:  13.981  SAR:   8.761
# accompaniment   ==> SDR:  15.200  SIR:  19.177  ISR:  23.932  SAR:  15.398
#
# [→] Separating: Invisible Familiars - Disturbing Wildlife
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  13.431  SIR:  20.411  ISR:  18.505  SAR:  14.117
# accompaniment   ==> SDR:  19.170  SIR:  26.399  ISR:  26.341  SAR:  20.035
#
# [→] Separating: James May - All Souls Moon
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.826  SIR:  16.504  ISR:  11.318  SAR:   8.146
# accompaniment   ==> SDR:  11.083  SIR:  16.807  ISR:  19.785  SAR:  13.050
#
# [→] Separating: James May - Dont Let Go
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.412  SIR:  13.782  ISR:  14.312  SAR:   9.539
# accompaniment   ==> SDR:  12.535  SIR:  18.967  ISR:  17.594  SAR:  14.603
#
# [→] Separating: James May - If You Say
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  10.448  SIR:  14.604  ISR:  16.853  SAR:  10.816
# accompaniment   ==> SDR:  10.898  SIR:  20.073  ISR:  16.314  SAR:  13.893
#
# [→] Separating: James May - On The Line
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.355  SIR:  13.247  ISR:  12.939  SAR:   9.938
# accompaniment   ==> SDR:  12.089  SIR:  17.664  ISR:  17.728  SAR:  14.574
#
# [→] Separating: Jay Menon - Through My Eyes
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.302  SIR:  13.507  ISR:  13.868  SAR:   8.601
# accompaniment   ==> SDR:  11.517  SIR:  17.253  ISR:  16.792  SAR:  12.548
#
# [→] Separating: Johnny Lokke - Promises & Lies
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.035  SIR:  12.185  ISR:  11.557  SAR:   6.351
# accompaniment   ==> SDR:  11.653  SIR:  17.188  ISR:  19.298  SAR:  13.234
#
# [→] Separating: Johnny Lokke - Whisper To A Scream
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.866  SIR:  11.887  ISR:   6.476  SAR:   4.687
# accompaniment   ==> SDR:  12.122  SIR:  12.713  ISR:  20.321  SAR:  11.928
#
# [→] Separating: Jokers, Jacks & Kings - Sea Of Leaves
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  10.571  SIR:  20.001  ISR:  15.106  SAR:  11.503
# accompaniment   ==> SDR:  12.352  SIR:  17.082  ISR:  21.072  SAR:  13.510
#
# [→] Separating: Leaf - Come Around
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   9.274  SIR:  18.670  ISR:   9.866  SAR:  12.973
# accompaniment   ==> SDR:  15.679  SIR:  16.849  ISR:  22.734  SAR:  21.006
#
# [→] Separating: Leaf - Summerghost
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.722  SIR:  16.206  ISR:   8.603  SAR:   9.608
# accompaniment   ==> SDR:  11.189  SIR:  13.352  ISR:  20.498  SAR:  15.274
#
# [→] Separating: Leaf - Wicked
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.645  SIR:  16.559  ISR:  11.435  SAR:   8.559
# accompaniment   ==> SDR:  11.953  SIR:  15.781  ISR:  17.109  SAR:  12.769
#
# [→] Separating: Lushlife - Toynbee Suite
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   2.851  SIR:  10.966  ISR:   5.189  SAR:   1.658
# accompaniment   ==> SDR:  20.987  SIR:  23.556  ISR:  32.654  SAR:  24.320
#
# [→] Separating: Matthew Entwistle - Dont You Ever
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  13.020  SIR:  18.862  ISR:  17.797  SAR:  12.725
# accompaniment   ==> SDR:  14.903  SIR:  18.288  ISR:  20.172  SAR:  13.348
#
# [→] Separating: Meaxic - Take A Step
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  13.569  SIR:  17.437  ISR:  14.529  SAR:  11.160
# accompaniment   ==> SDR:  14.814  SIR:  15.107  ISR:  20.851  SAR:  13.844
#
# [→] Separating: Meaxic - You Listen
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  11.432  SIR:  17.897  ISR:  11.874  SAR:  10.382
# accompaniment   ==> SDR:  16.121  SIR:  18.127  ISR:  24.303  SAR:  17.592
#
# [→] Separating: Music Delta - 80s Rock
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  12.119  SIR:  20.069  ISR:  15.000  SAR:  12.015
# accompaniment   ==> SDR:  14.869  SIR:  16.603  ISR:  22.774  SAR:  14.071
#
# [→] Separating: Music Delta - Beatles
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  11.626  SIR:  18.302  ISR:  20.840  SAR:  12.601
# accompaniment   ==> SDR:  13.180  SIR:  23.153  ISR:  19.247  SAR:  14.531
#
# [→] Separating: Music Delta - Britpop
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.651  SIR:  16.532  ISR:  12.404  SAR:   7.950
# accompaniment   ==> SDR:  11.431  SIR:  14.763  ISR:  16.615  SAR:  12.102
#
# [→] Separating: Music Delta - Country1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  10.844  SIR:  14.904  ISR:  18.801  SAR:  12.116
# accompaniment   ==> SDR:  14.024  SIR:  24.284  ISR:  15.599  SAR:  12.844
#
# [→] Separating: Music Delta - Disco
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  11.989  SIR:  20.231  ISR:  17.755  SAR:  11.272
# accompaniment   ==> SDR:  12.944  SIR:  22.470  ISR:  13.421  SAR:  13.741
#
# [→] Separating: Music Delta - Gospel
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  17.993  SIR:  23.402  ISR:  16.757  SAR:  13.832
# accompaniment   ==> SDR:  14.209  SIR:  17.681  ISR:  17.588  SAR:  13.709
#
# [→] Separating: Music Delta - Grunge
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.897  SIR:  13.551  ISR:  12.980  SAR:   8.220
# accompaniment   ==> SDR:  12.031  SIR:  17.693  ISR:  16.226  SAR:  12.938
#
# [→] Separating: Night Panther - Fire
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.734  SIR:  13.149  ISR:   9.828  SAR:   6.917
# accompaniment   ==> SDR:   7.817  SIR:  10.562  ISR:  13.244  SAR:   7.058
#
# [→] Separating: North To Alaska - All The Same
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  11.332  SIR:  16.019  ISR:  18.132  SAR:  12.357
# accompaniment   ==> SDR:  13.296  SIR:  21.674  ISR:  18.627  SAR:  14.816
#
# [→] Separating: Patrick Talbot - A Reason To Leave
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   4.362  SIR:  15.014  ISR:   6.971  SAR:   4.574
# accompaniment   ==> SDR:   7.891  SIR:   9.826  ISR:  18.763  SAR:  10.137
#
# [→] Separating: Patrick Talbot - Set Me Free
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.856  SIR:  10.021  ISR:  12.009  SAR:   9.685
# accompaniment   ==> SDR:   4.765  SIR:   9.976  ISR:   8.547  SAR:   7.717
#
# [→] Separating: Phre The Eon - Everybody's Falling Apart
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   9.122  SIR:  17.625  ISR:  13.334  SAR:   9.817
# accompaniment   ==> SDR:  13.047  SIR:  17.550  ISR:  18.513  SAR:  14.714
#
# [→] Separating: Port St Willow - Stay Even
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   3.369  SIR:  11.174  ISR:   6.775  SAR:   3.753
# accompaniment   ==> SDR:   9.462  SIR:  11.618  ISR:  20.939  SAR:  13.075
#
# [→] Separating: Remember December - C U Next Time
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.066  SIR:   3.982  ISR:   6.254  SAR:   2.850
# accompaniment   ==> SDR:   9.881  SIR:   6.419  ISR:  19.269  SAR:   6.900
#
# [→] Separating: Secret Mountains - High Horse
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.410  SIR:   8.220  ISR:  13.474  SAR:   8.064
# accompaniment   ==> SDR:   7.231  SIR:  12.722  ISR:  11.093  SAR:   9.113
#
# [→] Separating: Skelpolu - Human Mistakes
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   0.742  SIR:   4.276  ISR:   1.356  SAR:   0.849
# accompaniment   ==> SDR:   8.030  SIR:   8.478  ISR:  19.370  SAR:  17.073
#
# [→] Separating: Skelpolu - Together Alone
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.144  SIR:  13.175  ISR:  10.162  SAR:   8.508
# accompaniment   ==> SDR:  12.596  SIR:  12.244  ISR:  14.612  SAR:  10.605
#
# [→] Separating: Snowmine - Curfews
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.660  SIR:  12.909  ISR:   8.744  SAR:   6.233
# accompaniment   ==> SDR:  12.987  SIR:  13.917  ISR:  23.176  SAR:  14.214
#
# [→] Separating: Spike Mullings - Mike's Sulking
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   4.890  SIR:   7.603  ISR:   9.932  SAR:   6.690
# accompaniment   ==> SDR:   9.490  SIR:  13.579  ISR:  14.044  SAR:  10.398
#
# [→] Separating: St Vitus - Word Gets Around
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.150  SIR:   8.441  ISR:  10.269  SAR:   7.667
# accompaniment   ==> SDR:   6.969  SIR:   9.631  ISR:  10.168  SAR:   8.100
#
# [→] Separating: Steven Clark - Bounty
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   3.840  SIR:   7.237  ISR:   6.999  SAR:   3.793
# accompaniment   ==> SDR:   7.816  SIR:  10.770  ISR:  15.590  SAR:  11.013
#
# [→] Separating: Strand Of Oaks - Spacestation
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   9.184  SIR:  11.963  ISR:  18.254  SAR:  10.406
# accompaniment   ==> SDR:   9.651  SIR:  18.619  ISR:  13.286  SAR:  10.630
#
# [→] Separating: Sweet Lights - You Let Me Down
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   2.081  SIR:   7.474  ISR:   3.087  SAR:   1.854
# accompaniment   ==> SDR:   3.601  SIR:   4.002  ISR:  15.983  SAR:  11.084
#
# [→] Separating: Swinging Steaks - Lost My Way
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# ...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.425  SIR:  13.890  ISR:  11.569  SAR:   7.826
# accompaniment   ==> SDR:   9.477  SIR:  14.481  ISR:  14.879  SAR:  11.255
#
# [→] Separating: Moosmusic - Big Dummy Shake
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  11.753  SIR:  21.268  ISR:  17.305  SAR:  12.057
# accompaniment   ==> SDR:  14.084  SIR:  19.020  ISR:  22.074  SAR:  14.810
#
# [→] Separating: Motor Tapes - Shore
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  -0.544  SIR:  -8.023  ISR:   2.650  SAR:   4.722
# accompaniment   ==> SDR:  10.122  SIR:  12.897  ISR:  12.718  SAR:  15.341
#
# [→] Separating: Mu - Too Bright
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  12.179  SIR:  22.536  ISR:  18.059  SAR:  12.916
# accompaniment   ==> SDR:  14.898  SIR:  18.991  ISR:  23.462  SAR:  15.184
#
# [→] Separating: Nerve 9 - Pray For The Rain
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   6.849  SIR:  14.511  ISR:   9.173  SAR:   9.775
# accompaniment   ==> SDR:   7.803  SIR:   8.842  ISR:  17.241  SAR:  12.385
#
# [→] Separating: PR - Happy Daze
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  -1.695  SIR: -16.840  ISR:   0.209  SAR:  -1.006
# accompaniment   ==> SDR:  21.337  SIR:  29.382  ISR:  23.721  SAR:  25.100
#
# [→] Separating: PR - Oh No
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  -4.686  SIR: -11.736  ISR:   2.658  SAR:  -0.746
# accompaniment   ==> SDR:   8.563  SIR:  33.863  ISR:   8.901  SAR:  18.556
#
# [→] Separating: Punkdisco - Oral Hygiene
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   9.051  SIR:  19.591  ISR:  14.492  SAR:   9.658
# accompaniment   ==> SDR:  15.550  SIR:  20.942  ISR:  23.861  SAR:  16.026
#
# [→] Separating: Raft Monk - Tiring
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   4.752  SIR:  10.802  ISR:   7.972  SAR:   5.343
# accompaniment   ==> SDR:  10.158  SIR:  12.558  ISR:  19.729  SAR:  13.494
#
# [→] Separating: Sambasevam Shanmugam - Kaathaadi
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.385  SIR:  18.435  ISR:  11.606  SAR:   9.710
# accompaniment   ==> SDR:  14.016  SIR:  16.846  ISR:  20.979  SAR:  16.043
#
# [→] Separating: Secretariat - Borderline
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.221  SIR:  15.030  ISR:  10.308  SAR:   8.413
# accompaniment   ==> SDR:   9.111  SIR:  11.547  ISR:  17.197  SAR:  10.009
#
# [→] Separating: Secretariat - Over The Top
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.090  SIR:  19.157  ISR:  10.993  SAR:   8.975
# accompaniment   ==> SDR:  13.712  SIR:  19.489  ISR:  18.387  SAR:  15.638
#
# [→] Separating: Side Effects Project - Sing With Me
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  10.033  SIR:  13.613  ISR:  14.147  SAR:   8.814
# accompaniment   ==> SDR:  12.777  SIR:  18.392  ISR:  15.287  SAR:  11.916
#
# [→] Separating: Signe Jakobsen - What Have You Done To Me
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.970  SIR:  16.642  ISR:   9.146  SAR:   6.692
# accompaniment   ==> SDR:  12.243  SIR:  13.682  ISR:  22.450  SAR:  12.354
#
# [→] Separating: Skelpolu - Resurrection
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   0.393  SIR:   4.055  ISR:   0.560  SAR:  -0.719
# accompaniment   ==> SDR:   5.683  SIR:   6.539  ISR:  12.011  SAR:  15.090
#
# [→] Separating: Speak Softly - Broken Man
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   4.117  SIR:  12.018  ISR:   6.061  SAR:   5.273
# accompaniment   ==> SDR:  13.781  SIR:  14.991  ISR:  21.386  SAR:  18.146
#
# [→] Separating: Speak Softly - Like Horses
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   3.808  SIR:   7.114  ISR:   8.328  SAR:   5.916
# accompaniment   ==> SDR:   9.313  SIR:  12.074  ISR:  15.291  SAR:  12.745
#
# [→] Separating: The Doppler Shift - Atrophy
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.582  SIR:  19.054  ISR:   6.149  SAR:   4.939
# accompaniment   ==> SDR:  10.361  SIR:  11.232  ISR:  24.688  SAR:  12.787
#
# [→] Separating: The Easton Ellises (Baumi) - SDRNR
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   4.919  SIR:  12.399  ISR:   8.833  SAR:   5.261
# accompaniment   ==> SDR:   7.043  SIR:  11.227  ISR:  12.317  SAR:   9.856
#
# [→] Separating: The Easton Ellises - Falcon 69
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   4.209  SIR:   9.664  ISR:   6.824  SAR:   5.110
# accompaniment   ==> SDR:   9.021  SIR:  10.988  ISR:  16.270  SAR:  12.618
#
# [→] Separating: The Long Wait - Dark Horses
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.012  SIR:  14.000  ISR:  12.188  SAR:   8.669
# accompaniment   ==> SDR:  11.563  SIR:  16.977  ISR:  18.138  SAR:  12.829
#
# [→] Separating: The Mountaineering Club - Mallory
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   7.760  SIR:  13.841  ISR:  13.808  SAR:   8.226
# accompaniment   ==> SDR:  15.538  SIR:  21.783  ISR:  19.988  SAR:  16.504
#
# [→] Separating: The Sunshine Garcia Band - For I Am The Moon
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.783  SIR:  15.863  ISR:  15.885  SAR:   9.671
# accompaniment   ==> SDR:  14.344  SIR:  15.810  ISR:  18.915  SAR:  12.529
#
# [→] Separating: Timboz - Pony
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   4.512  SIR:  10.995  ISR:   6.704  SAR:   5.030
# accompaniment   ==> SDR:  13.637  SIR:  15.972  ISR:  22.964  SAR:  16.612
#
# [→] Separating: Tom McKenzie - Directions
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.961  SIR:  11.526  ISR:  10.153  SAR:   7.700
# accompaniment   ==> SDR:  15.805  SIR:  20.086  ISR:  19.651  SAR:  16.551
#
# [→] Separating: Triviul feat. The Fiend - Widow
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:  10.439  SIR:  14.861  ISR:  15.560  SAR:  11.018
# accompaniment   ==> SDR:  10.307  SIR:  14.680  ISR:  14.625  SAR:  10.484
#
# [→] Separating: We Fell From The Sky - Not You
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   5.409  SIR:  15.621  ISR:   8.776  SAR:   4.909
# accompaniment   ==> SDR:  12.896  SIR:  16.380  ISR:  24.245  SAR:  14.685
#
# [→] Separating: Zeno - Signs
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Apply unet for vocals_spectrogram
# INFO:tensorflow:Apply unet for accompaniment_spectrogram
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from pretrained_models/2stems/model
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# vocals          ==> SDR:   8.140  SIR:  13.404  ISR:  10.251  SAR:   6.511
# accompaniment   ==> SDR:  10.369  SIR:  12.879  ISR:  20.484  SAR:  11.175
#
# Spleeter separation complete.
